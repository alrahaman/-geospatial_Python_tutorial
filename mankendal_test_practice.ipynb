# %% [markdown]
# <a href="https://colab.research.google.com/github/alrahaman/-geospatial_Python_tutorial/blob/main/mankendal_test_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymannkendall matplotlib pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pymannkendall as mk

# %%
# Example: yearly rainfall (in mm)
years = [ 2019, 2020,2021,2022,2023,2024]
rainfall = [0.046088425,	0.053889544,	0.04727084,	0.052985798,	0.049350675,	0.050950724]

data = pd.DataFrame({'year': years, 'rainfall': rainfall})

# %%
result = mk.original_test(data['rainfall'])
print(result)
# Out:
# Mann_Kendall_Test(trend='no trend', h=np.False_, p=np.float64(0.7071142312899612), z=np.float64(0.3757345746510897), Tau=np.float64(0.2), s=np.float64(3.0), var_s=28.333333333333332, slope=np.float64(0.0008155624999999986), intercept=np.float64(0.04811179325000001))

# %% [markdown]
# graph edit by chat GPT

# %%
# --- Enhanced Plot Section ---

plt.figure(figsize=(10, 6))
plt.plot(data['year'], data['rainfall'], 'o-', color='#007acc', linewidth=2.2, markersize=6, label='Observed Data')
plt.plot(data['year'], trend_line, color='crimson', linestyle='--', linewidth=2.5, label=f"Sen's Slope = {slope:.3f}")

# Add annotation box with results
textstr = (
    # f"Trend: {trend}\n".............removing
    f"Tau: {tau_value:.3f}\n"
    f"p-value: {p_value:.2f}"
)
plt.gca().text(
    0.02, 0.95, textstr,
    transform=plt.gca().transAxes,
    fontsize=12,
    verticalalignment='top',
    bbox=dict(boxstyle='round,pad=0.5', facecolor='whitesmoke', alpha=0.9)
)

# Customize appearance
plt.title('Mann–Kendall Trend Analysis for December', fontsize=15, fontweight='bold', color='#333333', pad=15)
plt.xlabel('Year', fontsize=13)
plt.ylabel('CO (mol/m²)', fontsize=13)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=11, loc='lower right', frameon=True)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.tight_layout()
plt.savefig("/content/mann_kendall_trend_December.png", dpi=600, bbox_inches='tight')
plt.show()

# %%
from google.colab import files
files.download("/content/mann_kendall_trend_December.png")
